# %%
import sys, re
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import dok_matrix
import pandas as pd
import numpy as np

# %%
def print_word_pos_sentence(word_sentence, pos_sentence):
    assert len(word_sentence) == len(pos_sentence)
    for word, pos in zip(word_sentence, pos_sentence):
        print(f"{word}", end="\u3000")
    return

def read_file(path):
    with open(path, 'r', encoding='utf-8') as f:
        result = []
        text = f.read()
        f.close()
        result.append(text)
        return result

# %%
sw = ['的', '了', '和', '是', '就', '都', '而', '及', '與', '著', '或', 
'之', '後', '才', '元', '在', '不', '一個', '沒有', '我們', '你們', '妳們', 
'他們', '她們', '因此', '因為', '同年', '同時', '唯一', '去年', '原來',
 '加上', '剩下', '其中', '其他', '不到', '不如', '不止', '不錯', '之外',
  '不足', '千萬', '如果', '所有', '為了', '若是', '所以', '是否', '於是',
   '的確', '沒錯', '發現', '公布', '等於', '說法', '表示', '包括', 'text'
   , 'bit', 'ly', 'u7', 'cl', '3cmic7', 'd2xkns', '299', 'zania', '½ä¾',
    'kongtex', 'more']
path = 'datafile/EvaAir_text.txt'
corpus = read_file(path)
df = pd.read_csv('datafile/EvaAir_text.csv')
df1 = df[['text']]
text_data0 = np.array(df1)
text_data = text_data0.tolist()

collect_corpus = []

# %%
for i in text_data:

    clean_obj = re.sub('[【】《》「」*]', '', str(i))
    #clean_obj1 = re.sub("\n", "", clean_obj)
    if len(clean_obj) > 0:
        collect_corpus.append(clean_obj)

# %%
ws = WS("./data")

# %%
word_to_weight = {
    "長榮航空": 5,
    "EvaAir": 5,
    "BR": 2
}

# %%
dictionary = construct_dictionary(word_to_weight)
sentence_list = read_file(path)

# %%
word_sentence_list = ws(
    sentence_list,
    sentence_segmentation=True, # To consider delimiters
    segment_delimiter_set = {",", "。", ":", "?", "!", ";"}) # This is the defualt set of delimiters
    # recommend_dictionary = dictionary1, # words in this dictionary are encouraged
    # coerce_dictionary = dictionary2, # words in this dictionary are forced

# %%
word_sentence_list
# Out:
# [['no',
#   ',',
#   'text\n',
#   '319',
#   ',',
#   '"#',
#   '曬',
#   '年夜飯',
#   '抽',
#   '長榮',
#   '航空',
#   '新春',
#   '福袋\n',
#   '小潔',
#   '好奇',
#   '大家',
#   '團圓飯',
#   '都',
#   '吃',
#   '什麼',
#   '呢',
#   '?',
#   '🤔\n🎁',
#   '即日',
#   '起',
#   '至',
#   '\u3000',
#   '2/10',
#   ' ',
#   '23',
#   ':',
#   '59',
#   '在',
#   '下方',
#   '留言',
#   '\n曬出',
#   '你',
#   '家',
#   '的',
#   '經典',
#   '澎派',
#   '團圓',
#   '飯🍲🥗🍖\n5',
#   '名',
#   '幸運',
#   '的',
#   '得主',
#   '就',
#   '有',
#   '機會',
#   '得到',
#   '【',
#   '長榮',
#   '航空',
#   '新春福袋',
#   '】',
#   '哦\n',
#   '飛過',
#   '地球',
#   '一',
#   '圈',
#   '又',
#   '一',
#   '圈',
#   '✈\n',
#   '全',
#   '世界',
#   '都',
#   '是',
#   '長榮',
#   '航空',
#   '的',
#   '家人',
#   '\n',
#   '團圓',
#   '，',
#   '是',
#   '我們',
#   '共通',
#   '的',
#   '語言',
#   '👨👩👦👦\n',
#   '在',
#   '這',
#   '一',
#   '年',
#   '中',
#   '最',
#   '重要',
#   '的',
#   '日子',
#   '\n',
#   '長榮',
#   '航空',
#   '向',
#   '您',
#   '慶賀',
#   '闔家',
#   '團圓',
#   '、',
#   '喜迎',
#   '新年',
#   '🤗🎉\n#',
#   '長榮',
#   '航空',
#   '賀新春',
#   ' #',
#   '農曆',
#   '新年',
#   '快樂',
#   ' #HappyLunarNewYear"\n',
#   '320',
#   ',',
#   '"🎉',
#   '日本',
#   '旅遊',
#   '新',
#   '選擇',
#   '~',
#   '松山市',
#   '開賣',
#   '🎉\n🙋\u200d♀',
#   '松山市',
#   '在',
#   '哪兒',
#   '呢',
#   '❓\n',
#   '松山',
#   '位於',
#   '日本',
#   '四',
#   '國',
#   '，',
#   '緊鄰',
#   '著',
#   '美麗',
#   '的',
#   '瀨戶',
#   '內海',
#   '，',
#   '有',
#   '「',
#   '溫泉',
#   '、',
#   '城堡',
#   '、',
#   '文學',
#   '的',
#   '小鎮',
#   '」',
#   '之',
#   '稱',
#   '。',
#   '\n',
#   '小潔',
#   '推薦',
#   '行程',
#   '：',
#   '\n🔹',
#   '喜愛',
#   '愜意',
#   '漫遊',
#   '的',
#   '你',
#   '，',
#   '搭乘',
#   '「',
#   '少爺',
#   '列車',
#   '」',
#   '欣賞',
#   '街景',
#   '，',
#   '漫步',
#   '道',
#   '後',
#   '商店街',
#   '。',
#   '\n🔹',
#   '喜愛',
#   '運動',
#   '的',
#   '冒險',
#   '者',
#   '，',
#   '以',
#   '腳踏車',
#   '代步',
#   '暢遊',
#   '島波',
#   '海道',
#   '。',
#   '…',
#   ' More\n🔹',
#   '夜晚',
#   '別',
#   '錯過',
#   '擁有',
#   '日本',
#   '最',
#   '古老',
#   '溫泉',
#   '之',
#   '一',
#   '的',
#   '道後',
#   '溫泉',
#   '。',
#   '\n✈ ',
#   '立即',
#   '安排',
#   '2019年',
#   '的',
#   '旅程',
#   '吧',
#   '：',
#   'https',
#   ':',
#   '//goo.',
#   'gl/6pIkGR\n#BR110/109TPE-MYJ\n#',
#   '2019年',
#   '7月',
#   '18日',
#   '啟航',
#   '\n#',
#   '最',
#   '低',
#   '售價',
#   'TWD',
#   '7321',
#   '元',
#   '起',
#   '(',
#   '未',
#   '稅',
#   ')',
#   '\n',
#   '#',
#   '一定',
#   '要',
#   '吃',
#   'Madonna',
#   '少爺',
#   '糯米糰',
#   '也',
#   '不可',
#   '錯過',
#   '"\n321',
#   ',',
#   '"',
#   '【',
#   '春節',
#   '期間',
#   '旅遊',
#   '小叮嚀',
#   '】',
#   '\n',
#   '農曆',
#   '春節',
#   '期間',
#   '是否',
#   '已',
#   '安排',
#   '了',
#   '出國',
#   '行程',
#   '呢',
#   '?',
#   '\n',
#   '春節',
#   '期間',
#   '搭機',
#   '旅客',
#   '多👧🧒👦🧑👨👴🧓\n',
#   '長榮',
#   '與',
#   '立榮',
#   '航空',
#   '於',
#   '桃園',
#   '機場',
#   '出發',
#   '的',
#   '自營',
#   '航班',
#   '，',
#   '\n',
#   '即日',
#   '起',
#   '~',
#   '2/17',
#   '期間',
#   '的',
#   '櫃檯',
#   '服務',
#   '每日',
#   '最早',
#   '受理',
#   '報到',
#   '時間',
#   '為',
#   '04',
#   ':',
#   '15',
#   '，',
#   '\n',
#   '報到',
#   '結束',
#   '時間',
#   '由',
#   '航班',
#   '起飛',
#   '「',
#   '前',
#   '40',
#   ' ',
#   '分鐘',
#   '」',
#   '調整為',
#   '「',
#   '前',
#   '60',
#   '分鐘',
#   '」',
#   '，',
#   '…',
#   ' More\n',
#   '請',
#   '務必',
#   '於',
#   '航班',
#   '起飛',
#   '前',
#   '一',
#   '小時',
#   '完成',
#   '報到',
#   '及',
#   '行李',
#   '託運',
#   '，',
#   '並',
#   '儘速',
#   '前往',
#   '登機',
#   '，',
#   '\n登機',
#   '手續',
#   '將',
#   '於',
#   '航班',
#   '起飛',
#   '前',
#   '10',
#   ' ',
#   '分鐘',
#   '結束',
#   '。',
#   '\n',
#   '建議',
#   '可',
#   '於',
#   '航班',
#   '起飛',
#   '前',
#   '48',
#   '至',
#   '1.5',
#   '小時',
#   '內',
#   '，',
#   '使用',
#   '長榮',
#   '航空',
#   '手機',
#   'APP',
#   '或',
#   '長榮',
#   '航空',
#   '網站',
#   '辦理',
#   '報到',
#   '，',
#   '並',
#   '請',
#   '保留',
#   '充裕',
#   '的',
#   '時間',
#   '完成',
#   '行李',
#   '託運',
#   '及',
#   '通關',
#   '手續',
#   '\n',
#   '長榮',
#   '航空',
#   '祝',
#   '您',
#   '旅途',
#   '愉快',
#   '！',
#   '😃\n🤗',
#   '報到',
#   '小',
#   '撇步',
#   '：',
#   '\n',
#   '搭機',
#   '前',
#   '1.5',
#   '~',
#   '48',
#   '小時',
#   '使用',
#   '官網',
#   '、',
#   '手機',
#   'APP',
#   '報到',
#   '更',
#   '便利',
#   '。',
#   '\n官網',
#   '報到',
#   '：',
#   'https',
#   ':',
#   '//goo.',
#   'gl/LhJZES"\n',
#   '322',
#   ',',
#   '"',
#   '長榮',
#   '猜',
#   '一',
#   '猜',
#   '🤔\n',
#   '請問',
#   '大家',
#   '知道',
#   '這',
#   '是',
#   '哪',
#   '架',
#   '機型',
#   '的',
#   '內裝',
#   '嗎',
#   '?',
#   '✈\n',
#   '小潔',
#   '請',
#   '你',
#   '猜',
#   '一',
#   '猜',
#   '❓"\n',
#   '323',
#   ',',
#   '\n324',
#   ',',
#   '"',
#   '農曆',
#   '連假',
#   ' ',
#   '出國',
#   '選擇',
#   '多✈ ',
#   '旭川',
#   '(',
#   'AKJ',
#   ')',
#   '開賣',
#   '😍\n\n',
#   '小潔',
#   '連',
#   '行程',
#   '都',
#   '想好',
#   '囉🤭\n',
#   '早上',
#   ' ',
#   '旭山',
#   '動物園',
#   '看',
#   '企鵝',
#   '趴趴',
#   '走🐧🐧🐧\n',
#   '下午',
#   ' ',
#   '中午',
#   '雪',
#   '之',
#   '美術館',
#   '唱',
#   'Let It go 👩',
#   '\u200d🎤🎵🎶\n',
#   '晚上',
#   ' ',
#   '欣賞',
#   '冬祭',
#   '光雕',
#   '投影',
#   '及',
#   '煙火',
#   '❄⛄\n\n✈',
#   '立即',
#   '訂',
#   '票',
#   'GOGOGO',
#   '：',
#   'https',
#   ':',
#   '//goo',
#   '.',
#   'gl/6pIkGR\n\n#TPEAKJBR',
#   '136/',
#   '135',
#   '…',
#   ' More\n#',
#   '飛航',
#   '期間',
#   '2月',
#   '2日',
#   '至',
#   '2月',
#   '26日',
#   '\n#',
#   '優惠價',
#   'TWD',
#   '14400',
#   '元',
#   '起',
#   '(',
#   '未',
#   '稅',
#   ')',
#   '"\n325',
#   ',',
#   '"',
#   '天際',
#   '的',
#   '夢想',
#   '，',
#   '不變',
#   '的',
#   '翱翔\n',
#   '長榮',
#   '與',
#   '您',
#   '相伴',
#   '，',
#   '攜手',
#   '飛',
#   '向',
#   '下',
#   '一',
#   '個',
#   '十',
#   '年',
#   '~\n#10',
#   'yearschallenges\n#',
#   '長榮',
#   '航空',
#   '的',
#   '用心',
#   '你',
#   '看',
#   '得',
#   '到',
#   '\n',
#   '#',
#   '因為',
#   '你',
#   '是',
#   '長榮',
#   '不斷',
#   '前進',
#   '的',
#   '動力\n*',
#   '上',
#   '圖',
#   '：',
#   '2005年',
#   '起',
#   '加入',
#   '機隊',
#   '服務',
#   ' B777-',
#   '300',
#   'ER',
#   '彩帶機\n*',
#   '下圖',
#   '：',
#   '2018年',
#   '起',
#   '加入',
#   '機隊',
#   '服務',
#   ' ',
#   '台灣',
#   '首',
#   '架',
#   'B787-9 ',
#   '夢幻',
#   '客機',
#   '"\n326',
#   ',',
#   '"',
#   '【',
#   '小潔',
#   '與',
#   '大師',
#   '對談',
#   '🗣 ~Jason ',
#   'Wu',
#   '吳季剛',
#   '】',
#   '\n\n',
#   '小潔',
#   '懷抱',
#   '著',
#   '無比',
#   '崇敬',
#   '的',
#   '心情',
#   '，',
#   '與',
#   '我',
#   '的',
#   '時尚',
#   '偶像',
#   '-',
#   '吳季剛',
#   '見面',
#   '了',
#   '🤗\n\n',
#   '在',
#   '慵懶',
#   '的',
#   '午後',
#   '，',
#   '細細',
#   '聆聽',
#   'Jason',
#   '說明',
#   '此',
#   '次',
#   '長榮',
#   '新款',
#   '睡衣',
#   '的',
#   '設計',
#   '理念',
#   '👂\n',
#   '舒適',
#   '、',
#   '美觀',
#   '的',
#   '細膩',
#   '設計',
#   '，',
#   '灰',
#   '、',
#   '黃',
#   '跳色',
#   '搭配',
#   '的',
#   '驚艷',
#   '巧思',
#   '，',
#   '\n',
#   '即使',
#   '是',
#   '睡衣',
#   '，',
#   '實用',
#   '與',
#   '時尚',
#   '不再',
#   '衝突',
#   '🛌\n\n#',
#   '吳季剛',
#   'x',
#   '長榮',
#   '航空',
#   '星光',
#   '聯名',
#   '時尚',
#   '新款',
#   '睡衣\n',
#   '#',
#   '2019年',
#   '1月',
#   '中',
#   '下旬',
#   '與',
#   '你',
#   '機',
#   '上',
#   '相遇',
#   '…',
#   ' More\n\n',
#   '更多',
#   '新品',
#   '回顧',
#   '：',
#   'https',
#   ':',
#   '//goo',
#   '.',
#   'gl/fb2v7J\n🌟',
#   '想要',
#   '第一',
#   '時間',
#   '收到',
#   '粉絲團',
#   '訊息',
#   '，',
#   '要',
#   '記得',
#   '設定',
#   '✔',
#   '搶先',
#   '看',
#   '喔"\n327',
#   ',',
#   '"',
#   '就',
#   '在',
#   '今夜',
#   '(',
#   '1/18',
#   ')',
#   '，',
#   '立即',
#   '加入',
#   '長榮',
#   'LINE',
#   '好友',
#   '📱\n',
#   '今晚',
#   '8點',
#   '準時',
#   '好康',
#   '告訴',
#   '你',
#   '！',
#   '🕗\n\n',
#   '加',
#   '好友',
#   '捷徑',
#   '這邊',
#   '請',
#   '💁\nhttps',
#   ':',
#   '//line',
#   '.',
#   'me/R/ti/p/%',
#   '40',
#   'evaair\n\n#',
#   '2019',
#   '跟著',
#   '長榮',
#   '旅行',
#   '去',
#   '🧳\n#',
#   '今晚',
#   '好康',
#   '讓',
#   '明天',
#   '補班',
#   '也',
#   '不',
#   '憂鬱\n',
#   '#',
#   '官方',
#   '帳號',
#   '搜尋',
#   '長榮',
#   '航空',
#   'EVAAIR"\n',
#   '328',
#   ',',
#   '"',
#   '長榮',
#   '領航',
#   '✈',
#   '飛',
#   '在',
#   '最',
#   '前方',
#   '\n',
#   '國籍',
#   '航空',
#   '首推',
#   'Google ',
#   'Pay',
#   '、',
#   'Apple ',
#   'Pay',
#   '支付',
#   '\n\n',
#   '即日',
#   '起',
#   '，',
#   '透過',
#   ' ',
#   '長榮',
#   '航空官',
#   '網💻 / EVA MOBILE APP📱\n',
#   '購買',
#   '台灣',
#   '出發',
#   '的',
#   '長榮',
#   '機票',
#   '，',
#   '可',
#   '使用',
#   'Google Pay',
#   '及',
#   'Apple Pay',
#   '支付',
#   '功能',
#   '囉',
#   '！',
#   '\n\n🏃\u200d♀',
#   '還',
#   '等',
#   '什麼',
#   '呢',
#   '?',
#   '現在',
#   '就',
#   '開始',
#   '規劃',
#   '2019',
#   '的',
#   '旅行',
#   '吧',
#   '~✈\n\n#',
#   '其他',
#   '地區',
#   '出發',
#   '將',
#   '陸續',
#   '上線',
#   '敬請',
#   '期待',
#   '\n#',
#   '小潔',
#   '就是',
#   '想',
#   '為',
#   '你',
#   '提供',
#   '更多',
#   '便利',
#   '服務',
#   '\n',
#   '#',
#   '長榮',
#   '航空',
#   '購',
#   '票',
#   '更',
#   'Easy🤩"\n',
#   '329',
#   ',',
#   '"',
#   '【',
#   '5/24',
#   '起',
#   ' ',
#   '西雅圖',
#   '增飛',
#   '三',
#   '班',
#   '】',
#   '\n\n',
#   '想',
#   '去',
#   '星巴克',
#   '創始店',
#   '當',
#   '文青',
#   '？',
#   '☕ ',
#   '️\n',
#   '或是',
#   '登上',
#   '太空',
#   '針塔',
#   '欣賞',
#   '美景',
#   '？',
#   '🌃\n',
#   '還是',
#   '去',
#   '派克',
#   '市場',
#   '吃',
#   '海鮮',
#   '看丟',
#   '魚秀',
#   '？',
#   '🦞\n\n',
#   '自',
#   '2019',
#   '/',
#   '5',
#   '/24',
#   '起',
#   '，',
#   '\n',
#   '長榮',
#   '航空',
#   '增飛',
#   '每',
#   '週三/',
#   '五/日',
#   '桃園',
#   '-',
#   '西雅圖',
#   '航班',
#   '，',
#   '\n週',
#   '週十',
#   '班',
#   '帶',
#   '您',
#   '前往',
#   '翡翠',
#   '之',
#   '城',
#   '！',
#   '\n\n',
#   '詳細',
#   '資訊',
#   '請',
#   '點👉',
#   '：',
#   'https',
#   ':',
#   '//goo.',
#   'gl/PbkvPS"\n',
#   '330',
#   ',',
#   '"',
#   '【',
#   '🎉',
#   '長榮',
#   '航空',
#   '六',
#   '度',
#   '蟬連',
#   'AirlineRatings',
#   '.com',
#   '全球',
#   '最',
#   '安全',
#   '航空',
#   '公司',
#   '】',
#   '\n\n',
#   '小潔',
#   '很',
#   '榮幸',
#   '與',
#   '各位',
#   '分享',
#   '好',
#   '消息📣',
#   '，',
#   '近日',
#   '由',
#   '國際',
#   '知名',
#   '航空',
#   '專業',
#   '評鑑',
#   '網站',
#   'Airline',
#   'Ratings',
#   '.',
#   'com',
#   '公布',
#   '最',
#   '新',
#   '飛航',
#   '安全',
#   '評比',
#   '結果',
#   '，',
#   '長榮',
#   '航空',
#   '連續',
#   ...]]

# %%
cut_corpus = []
for i in word_sentence_list:
    cut_corpus.append(' '.join(i))
    
vertor = CountVectorizer(stop_words=sw)
td_martix = vertor.fit_transform(cut_corpus)

# %%
td_martix.shape
vertor.vocabulary_.keys()
# Out:
# dict_keys(['no', '319', '年夜飯', '長榮', '航空', '新春', '福袋', '小潔', '好奇', '大家', '團圓飯', '什麼', '即日', '10', '23', '59', '下方', '留言', '曬出', '經典', '澎派', '團圓', '幸運', '得主', '機會', '得到', '新春福袋', '飛過', '地球', '世界', '家人', '共通', '語言', '重要', '日子', '慶賀', '闔家', '喜迎', '新年', '賀新春', '農曆', '快樂', 'happylunarnewyear', '320', '日本', '旅遊', '選擇', '松山市', '開賣', '哪兒', '松山', '位於', '緊鄰', '美麗', '瀨戶', '內海', '溫泉', '城堡', '文學', '小鎮', '推薦', '行程', '喜愛', '愜意', '漫遊', '搭乘', '少爺', '列車', '欣賞', '街景', '漫步', '商店街', '運動', '冒險', '腳踏車', '代步', '暢遊', '島波', '海道', '夜晚', '錯過', '擁有', '古老', '道後', '立即', '安排', '2019年', '旅程', 'https', 'goo', 'gl', '6pikgr', 'br110', '109tpe', 'myj', '7月', '18日', '啟航', '售價', 'twd', '7321', '一定', 'madonna', '糯米糰', '不可', '321', '春節', '期間', '小叮嚀', '出國', '搭機', '旅客', '立榮', '桃園', '機場', '出發', '自營', '航班', '17', '櫃檯', '服務', '每日', '最早', '受理', '報到', '時間', '04', '15', '結束', '起飛', '40', '分鐘', '調整為', '60', '務必', '小時', '完成', '行李', '託運', '儘速', '前往', '登機', '手續', '建議', '48', '使用', '手機', 'app', '網站', '辦理', '保留', '充裕', '通關', '旅途', '愉快', '撇步', '官網', '便利', 'lhjzes', '322', '請問', '知道', '機型', '內裝', '323', '324', '連假', '旭川', 'akj', '想好', '早上', '旭山', '動物園', '企鵝', '趴趴', '下午', '中午', '美術館', 'let', 'it', 'go', '晚上', '冬祭', '光雕', '投影', '煙火', 'gogogo', 'tpeakjbr', '136', '135', '飛航', '2月', '2日', '26日', '優惠價', '14400', '325', '天際', '夢想', '不變', '翱翔', '相伴', '攜手', 'yearschallenges', '用心', '不斷', '前進', '動力', '2005年', '加入', '機隊', 'b777', '300', 'er', '彩帶機', '下圖', '2018年', '台灣', 'b787', '夢幻', '客機', '326', '大師', '對談', 'jason', 'wu', '吳季剛', '懷抱', '無比', '崇敬', '心情', '時尚', '偶像', '見面', '慵懶', '午後', '細細', '聆聽', '說明', '新款', '睡衣', '設計', '理念', '舒適', '美觀', '細膩', '跳色', '搭配', '驚艷', '巧思', '即使', '實用', '不再', '衝突', '星光', '聯名', '1月', '下旬', '相遇', '更多', '新品', '回顧', 'fb2v7j', '想要', '第一', '收到', '粉絲團', '訊息', '記得', '設定', '搶先', '327', '今夜', '18', 'line', '好友', '今晚', '8點', '準時', '好康', '告訴', '捷徑', '這邊', 'me', 'ti', 'evaair', '2019', '跟著', '旅行', '明天', '補班', '憂鬱', '官方', '帳號', '搜尋', '328', '領航', '前方', '國籍', '首推', 'google', 'pay', 'apple', '支付', '透過', '航空官', 'eva', 'mobile', '購買', '機票', '功能', '現在', '開始', '規劃', '地區', '陸續', '上線', '敬請', '期待', '就是', '提供', 'easy', '329', '24', '西雅圖', '增飛', '星巴克', '創始店', '文青', '或是', '登上', '太空', '針塔', '美景', '還是', '派克', '市場', '海鮮', '看丟', '魚秀', '週三', '週十', '翡翠', '詳細', '資訊', 'pbkvps', '330', '蟬連', 'airlineratings', 'com', '全球', '安全', '公司', '榮幸', '各位', '分享', '消息', '近日', '國際', '知名', '專業', '評鑑', 'airline', 'ratings', '評比', '結果', '連續', '榮登', 'top', '20', '行列', '堅信', '核心', '價值', '以及', '承諾', '全體', '同仁', '努力', '首要', '目標', '詳情', '參見', '企業', '社會', '責任', '報告書', 'k5', 'hfcw', '揚翼', '無慮', '追求', '絕不', '妥協', '航空業', '堅持', '跨越', '紅線', '出處', '章節', '健全', '管理', '體系', '331', '恭喜', '旗開', '得勝', '澳洲', '公開賽', '加油', '詹詠然', 'latisha', 'chan', 'january', '12', 'at', '21', 'am', 'facebook', 'creator', 'for', 'ios', '第二', '迎來', '年度', '冠軍', '荷巴特', '比賽', '海風', '氣候', '溫差', '挑戰', '能夠', '克服', '環境', '因素', '拿下', '對於', '自己', '肯定', '2nd', 'week', 'of', 'the', 'year', '1st', 'season', '生涯', '30', '達成', '詹皓晴', 'angel', 'hobart', 'international', 'australian', 'open', 'series', '332', '上海', '加班機', '報喜', '獻上', '高雄', '挑選', '快點', '手刀', '搶購', 'yebdcy', '333', '飛行', '一直', '以來', '頂級', '品質', '馬上', '歷屆', '眾多', '明星', '商品', '用品', '發表會', '334', '青森', 'aoj', '今日', '11', '蘋果', 'www', '景點', 'factory', '買買', '弘前城', '藝術', '創作', '櫻花', '春吹', 'jul', '開航', '8450', '飛飛', '這裡', 'zhmlx7', 'android', 'jtwfpg', '335', '波音', '787', '首航', '紀錄', '2018', 'nov', '01', '航空迷', '熱血', '沸騰', '香港', '即便', '天空', '濛濛細雨', '乘客', '隨著', '機長', '感性', '廣播', '飛機', '平穩', '展開', '記錄下', '篇章', '呼叫', '一樣', '飛機迷', '00', '紀錄片', '原因', '獲得', '相關', '精美', '禮物', '20181101br867', '1030tpe', 'takeoff', '1200', 'hkg', 'touchdown', '336', '悠遊', '抽好', '饗宴', '心靈', '開拓', '視野', '台北', '當代', '博覽會', '展出', '來自', '九十', '頂尖', '畫廊', '作品', '雙眼', '徜徉', '只要', '10日', '朋友', '說出', '心目中', '雙人', '票券', 'ex', '阿榮', 'uni', 'air', '佛羅倫斯', '這樣', '覺得', '20日', '南港', '展覽館', '1館', '支持', '藝文', '活動', '不餘遺力', '畫作', 'atsushi', 'kaga', 'melancholia', 'with', 'food', '2014', '337', '提醒', '不要', '攜帶', '肉品', '返台', '常常', '國外', '粉絲', '海外', '伴手禮', '違 ...

# %%
TFIDF = TfidfTransformer()
TFIDF_matrix = TFIDF.fit_transform(td_martix)
TFIDF.idf_
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
matrix = TFIDF_matrix.toarray()
new_matrix = np.squeeze(matrix)

# %%
df_res = pd.DataFrame(TFIDF_matrix.T.toarray(), index=vertor.vocabulary_.keys())
df_res.columns = ['tag']
df_res
# Out:
#                  tag
# no          0.051262
# 319         0.019821
# 年夜飯         0.000171
# 長榮          0.000171
# 航空          0.000171
# 新春          0.005810
# 福袋          0.000513
# 小潔          0.000171
# 好奇          0.000171
# 大家          0.000171
# 團圓飯         0.000171
# 什麼          0.000342
# 即日          0.000171
# 10          0.000171
# 23          0.004101
# 59          0.000171
# 下方          0.000171
# 留言          0.000171
# 曬出          0.004101
# 經典          0.000171
# 澎派          0.000171
# 團圓          0.000171
# 幸運          0.003759
# 得主          0.000171
# 機會          0.000171
# 得到          0.000171
# 新春福袋        0.005639
# 飛過          0.000171
# 地球          0.000171
# 世界          0.000171
# ...              ...
# discount    0.000171
# evaloves88  0.000342
# 1985        0.000171
# 穩當          0.000171
# 空橋          0.000171
# 信賴          0.000342
# 輝映          0.001709
# 1986        0.000513
# exhibition  0.000171
# 1987        0.000171
# 捐助          0.000171
# 災民          0.000171
# 重建家         0.000171
# 苓雅          0.000342
# 前鎮          0.000342
# 高雄市         0.000171
# 基金          0.000171
# 人饑己饑        0.000683
# 人溺己溺        0.000171
# 重建          0.000171
# 1988        0.000171
# 鋼日          0.000171
# 岱鋼日         0.000171
# 開球          0.000171
# 投出          0.000171
# strike      0.000171
# 1989        0.000342
# 普天同慶        0.000342
# 刮鬍刀         0.000342
# 過時          0.001709
#
# [19318 rows x 1 columns]

# %%
df_key = list(vertor.vocabulary_.keys())
new_key = {
    "tag":df_key,
    "rate":new_matrix
}
df_res1 = pd.DataFrame(new_key)

# %%
df_final = df_res1.sort_values(by=['rate'], ascending=False)
df_final
# Out:
#                       tag      rate
# 18022                 開頭話  0.530396
# 15808                peng  0.430434
# 3548                  482  0.271862
# 3561                   紙本  0.271862
# 9728                 1099  0.202999
# 3743                  496  0.180444
# 12949                  過機  0.154984
# 3742                   來襲  0.126447
# 8952                coast  0.124739
# 12505                1385  0.106968
# 3296             envoyage  0.096544
# 14945                 陳彥廷  0.083558
# 18775                1939  0.072451
# 10385                 打造出  0.071426
# 6219                  11日  0.071426
# 8049       milesforsmiles  0.070742
# 11668                 意志力  0.069033
# 7008                   帶動  0.068350
# 4008                  ger  0.067666
# 15804                 簡蟲蟲  0.065787
# 3662                  細細道  0.064078
# 12066                  品酒  0.062711
# 12500                1384  0.061002
# 5972        happyholidays  0.060661
# 12491                1383  0.059635
# 8034                  900  0.057927
# 2953                 臺虎精釀  0.056901
# 60                     推薦  0.053655
# 0                      no  0.051262
# 7157                   開銷  0.049895
# ...                   ...       ...
# 8850    10204498948896870  0.000171
# 8851                 winy  0.000171
# 8852                  tao  0.000171
# 8818                   領銜  0.000171
# 8816                  988  0.000171
# 8774                   公主  0.000171
# 8789                   臺中  0.000171
# 1365                   方頭  0.000171
# 8776                   力作  0.000171
# 8778                magic  0.000171
# 8779                   加冕  0.000171
# 8780                   首演  0.000171
# 8783                 1080  0.000171
# 8784                   年代  0.000171
# 8785                   啟售  0.000171
# 1364                   尖頭  0.000171
# 8788                  fri  0.000171
# 8790                  歌劇院  0.000171
# 8815   theinfinitylounges  0.000171
# 1363                 用武之地  0.000171
# 8799                  986  0.000171
# 8800                   固定  0.000171
# 1362                   頸枕  0.000171
# 8804                  159  0.000171
# 8809                  987  0.000171
# 8810                   名列  0.000171
# 8812              lounges  0.000171
# 1361                   晚安  0.000171
# 8814               btf0rw  0.000171
# 1102                   料理  0.000171
#
# [19318 rows x 2 columns]
